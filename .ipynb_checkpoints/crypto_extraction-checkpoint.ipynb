# %% [markdown]
# ### Bitcoin historic data (extraction)
# **Working on it...**
#
# Good [website](http://www.cryptodatadownload.com/) to start with.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Package installation for financial visulizations
# !pip install --upgrade mplfinance
import mplfinance as mpf

plt.style.use('seaborn')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
btc_path = 'C:/Users/Javi/Desktop/cryptocurrency_predictor/data/crypto/Bitstamp_BTCUSD_minute.csv'
columns_to_use = ['unix', 'symbol', 'open', 'high', 'low', 'close', 'Volume USD']

btc = pd.read_csv(btc_path, header=1, usecols=columns_to_use)

# %%
df_btc = btc.copy()
df_btc.head()
# Out:
#          unix   symbol      open      high       low     close     Volume USD
# 0  1612419420  BTC/USD  37824.45  37841.61  37818.00  37841.61   24452.017394
# 1  1612419360  BTC/USD  37843.82  37843.82  37786.72  37835.09  237078.154768
# 2  1612419300  BTC/USD  37830.12  37856.55  37821.65  37843.03   18681.940238
# 3  1612419240  BTC/USD  37827.64  37830.12  37812.91  37830.12   14978.478141
# 4  1612419180  BTC/USD  37847.88  37849.47  37823.83  37826.96  170026.711261

# %% [markdown]
# This is so fucking great!!! Very lucky to have this amount of bitcoin historic data minutely :))))

# %%
# Let's make a column with a proper date
from datetime import datetime

# %%
# %%time

df_btc['unix'].apply(lambda x: datetime.fromtimestamp(x))
# Out:
# Wall time: 56.8 ms
# 0       2021-02-04 07:17:00
# 1       2021-02-04 07:16:00
# 2       2021-02-04 07:15:00
# 3       2021-02-04 07:14:00
# 4       2021-02-04 07:13:00
#                 ...
# 67139   2020-11-22 09:01:00
# 67140   2020-11-22 09:00:00
# 67141   2020-11-22 08:59:00
# 67142   2020-11-22 08:58:00
# 67143   2020-11-22 08:57:00
# Name: unix, Length: 67144, dtype: datetime64[ns]

# %%
# %%time

[datetime.fromtimestamp(ts) for ts in df_btc['unix']]
# Out:
# Wall time: 65 ms
# [datetime.datetime(2021, 2, 4, 7, 17),
#  datetime.datetime(2021, 2, 4, 7, 16),
#  datetime.datetime(2021, 2, 4, 7, 15),
#  datetime.datetime(2021, 2, 4, 7, 14),
#  datetime.datetime(2021, 2, 4, 7, 13),
#  datetime.datetime(2021, 2, 4, 7, 12),
#  datetime.datetime(2021, 2, 4, 7, 11),
#  datetime.datetime(2021, 2, 4, 7, 10),
#  datetime.datetime(2021, 2, 4, 7, 9),
#  datetime.datetime(2021, 2, 4, 7, 8),
#  datetime.datetime(2021, 2, 4, 7, 7),
#  datetime.datetime(2021, 2, 4, 7, 6),
#  datetime.datetime(2021, 2, 4, 7, 5),
#  datetime.datetime(2021, 2, 4, 7, 4),
#  datetime.datetime(2021, 2, 4, 7, 3),
#  datetime.datetime(2021, 2, 4, 7, 2),
#  datetime.datetime(2021, 2, 4, 7, 1),
#  datetime.datetime(2021, 2, 4, 7, 0),
#  datetime.datetime(2021, 2, 4, 6, 59),
#  datetime.datetime(2021, 2, 4, 6, 58),
#  datetime.datetime(2021, 2, 4, 6, 57),
#  datetime.datetime(2021, 2, 4, 6, 56),
#  datetime.datetime(2021, 2, 4, 6, 55),
#  datetime.datetime(2021, 2, 4, 6, 54),
#  datetime.datetime(2021, 2, 4, 6, 53),
#  datetime.datetime(2021, 2, 4, 6, 52),
#  datetime.datetime(2021, 2, 4, 6, 51),
#  datetime.datetime(2021, 2, 4, 6, 50),
#  datetime.datetime(2021, 2, 4, 6, 49),
#  datetime.datetime(2021, 2, 4, 6, 48),
#  datetime.datetime(2021, 2, 4, 6, 47),
#  datetime.datetime(2021, 2, 4, 6, 46),
#  datetime.datetime(2021, 2, 4, 6, 45),
#  datetime.datetime(2021, 2, 4, 6, 44),
#  datetime.datetime(2021, 2, 4, 6, 43),
#  datetime.datetime(2021, 2, 4, 6, 42),
#  datetime.datetime(2021, 2, 4, 6, 41),
#  datetime.datetime(2021, 2, 4, 6, 40),
#  datetime.datetime(2021, 2, 4, 6, 39),
#  datetime.datetime(2021, 2, 4, 6, 38),
#  datetime.datetime(2021, 2, 4, 6, 37),
#  datetime.datetime(2021, 2, 4, 6, 36),
#  datetime.datetime(2021, 2, 4, 6, 35),
#  datetime.datetime(2021, 2, 4, 6, 34),
#  datetime.datetime(2021, 2, 4, 6, 33),
#  datetime.datetime(2021, 2, 4, 6, 32),
#  datetime.datetime(2021, 2, 4, 6, 31),
#  datetime.datetime(2021, 2, 4, 6, 30),
#  datetime.datetime(2021, 2, 4, 6, 29),
#  datetime.datetime(2021, 2, 4, 6, 28),
#  datetime.datetime(2021, 2, 4, 6, 27),
#  datetime.datetime(2021, 2, 4, 6, 26),
#  datetime.datetime(2021, 2, 4, 6, 25),
#  datetime.datetime(2021, 2, 4, 6, 24),
#  datetime.datetime(2021, 2, 4, 6, 23),
#  datetime.datetime(2021, 2, 4, 6, 22),
#  datetime.datetime(2021, 2, 4, 6, 21),
#  datetime.datetime(2021, 2, 4, 6, 20),
#  datetime.datetime(2021, 2, 4, 6, 19),
#  datetime.datetime(2021, 2, 4, 6, 18),
#  datetime.datetime(2021, 2, 4, 6, 17),
#  datetime.datetime(2021, 2, 4, 6, 16),
#  datetime.datetime(2021, 2, 4, 6, 15),
#  datetime.datetime(2021, 2, 4, 6, 14),
#  datetime.datetime(2021, 2, 4, 6, 13),
#  datetime.datetime(2021, 2, 4, 6, 12),
#  datetime.datetime(2021, 2, 4, 6, 11),
#  datetime.datetime(2021, 2, 4, 6, 10),
#  datetime.datetime(2021, 2, 4, 6, 9),
#  datetime.datetime(2021, 2, 4, 6, 8),
#  datetime.datetime(2021, 2, 4, 6, 7),
#  datetime.datetime(2021, 2, 4, 6, 6),
#  datetime.datetime(2021, 2, 4, 6, 5),
#  datetime.datetime(2021, 2, 4, 6, 4),
#  datetime.datetime(2021, 2, 4, 6, 3),
#  datetime.datetime(2021, 2, 4, 6, 2),
#  datetime.datetime(2021, 2, 4, 6, 1),
#  datetime.datetime(2021, 2, 4, 6, 0),
#  datetime.datetime(2021, 2, 4, 5, 59),
#  datetime.datetime(2021, 2, 4, 5, 58),
#  datetime.datetime(2021, 2, 4, 5, 57),
#  datetime.datetime(2021, 2, 4, 5, 56),
#  datetime.datetime(2021, 2, 4, 5, 55),
#  datetime.datetime(2021, 2, 4, 5, 54),
#  datetime.datetime(2021, 2, 4, 5, 53),
#  datetime.datetime(2021, 2, 4, 5, 52),
#  datetime.datetime(2021, 2, 4, 5, 51),
#  datetime.datetime(2021, 2, 4, 5, 50),
#  datetime.datetime(2021, 2, 4, 5, 49),
#  datetime.datetime(2021, 2, 4, 5, 48),
#  datetime.datetime(2021, 2, 4, 5, 47),
#  datetime.datetime(2021, 2, 4, 5, 46),
#  datetime.datetime(2021, 2, 4, 5, 45),
#  datetime.datetime(2021, 2, 4, 5, 44),
#  datetime.datetime(2021, 2, 4, 5, 43),
#  datetime.datetime(2021, 2, 4, 5, 42),
#  datetime.datetime(2021, 2, 4, 5, 41),
#  datetime.datetime(2021, 2, 4, 5, 40),
#  datetime.datetime(2021, 2, 4, 5, 39),
#  datetime.datetime(2021, 2, 4, 5, 38),
#  datetime.datetime(2021, 2, 4, 5, 37),
#  datetime.datetime(2021, 2, 4, 5, 36),
#  datetime.datetime(2021, 2, 4, 5, 35),
#  datetime.datetime(2021, 2, 4, 5, 34),
#  datetime.datetime(2021, 2, 4, 5, 33),
#  datetime.datetime(2021, 2, 4, 5, 32),
#  datetime.datetime(2021, 2, 4, 5, 31),
#  datetime.datetime(2021, 2, 4, 5, 30),
#  datetime.datetime(2021, 2, 4, 5, 29),
#  datetime.datetime(2021, 2, 4, 5, 28),
#  datetime.datetime(2021, 2, 4, 5, 27),
#  datetime.datetime(2021, 2, 4, 5, 26),
#  datetime.datetime(2021, 2, 4, 5, 25),
#  datetime.datetime(2021, 2, 4, 5, 24),
#  datetime.datetime(2021, 2, 4, 5, 23),
#  datetime.datetime(2021, 2, 4, 5, 22),
#  datetime.datetime(2021, 2, 4, 5, 21),
#  datetime.datetime(2021, 2, 4, 5, 20),
#  datetime.datetime(2021, 2, 4, 5, 19),
#  datetime.datetime(2021, 2, 4, 5, 18),
#  datetime.datetime(2021, 2, 4, 5, 17),
#  datetime.datetime(2021, 2, 4, 5, 16),
#  datetime.datetime(2021, 2, 4, 5, 15),
#  datetime.datetime(2021, 2, 4, 5, 14),
#  datetime.datetime(2021, 2, 4, 5, 13),
#  datetime.datetime(2021, 2, 4, 5, 12),
#  datetime.datetime(2021, 2, 4, 5, 11),
#  datetime.datetime(2021, 2, 4, 5, 10),
#  datetime.datetime(2021, 2, 4, 5, 9),
#  datetime.datetime(2021, 2, 4, 5, 8),
#  datetime.datetime(2021, 2, 4, 5, 7),
#  datetime.datetime(2021, 2, 4, 5, 6),
#  datetime.datetime(2021, 2, 4, 5, 5),
#  datetime.datetime(2021, 2, 4, 5, 4),
#  datetime.datetime(2021, 2, 4, 5, 3),
#  datetime.datetime(2021, 2, 4, 5, 2),
#  datetime.datetime(2021, 2, 4, 5, 1),
#  datetime.datetime(2021, 2, 4, 5, 0),
#  datetime.datetime(2021, 2, 4, 4, 59),
#  datetime.datetime(2021, 2, 4, 4, 58),
#  datetime.datetime(2021, 2, 4, 4, 57),
#  datetime.datetime(2021, 2, 4, 4, 56),
#  datetime.datetime(2021, 2, 4, 4, 55),
#  datetime.datetime(2021, 2, 4, 4, 54),
#  datetime.datetime(2021, 2, 4, 4, 53),
#  datetime.datetime(2021, 2, 4, 4, 52),
#  datetime.datetime(2021, 2, 4, 4, 51),
#  datetime.datetime(2021, 2, 4, 4, 50),
#  datetime.datetime(2021, 2, 4, 4, 49),
#  datetime.datetime(2021, 2, 4, 4, 48),
#  datetime.datetime(2021, 2, 4, 4, 47),
#  datetime.datetime(2021, 2, 4, 4, 46),
#  datetime.datetime(2021, 2, 4, 4, 45),
#  datetime.datetime(2021, 2, 4, 4, 44),
#  datetime.datetime(2021, 2, 4, 4, 43),
#  datetime.datetime(2021, 2, 4, 4, 42),
#  datetime.datetime(2021, 2, 4, 4, 41),
#  datetime.datetime(2021, 2, 4, 4, 40),
#  datetime.datetime(2021, 2, 4, 4, 39),
#  datetime.datetime(2021, 2, 4, 4, 38),
#  datetime.datetime(2021, 2, 4, 4, 37),
#  datetime.datetime(2021, 2, 4, 4, 36),
#  datetime.datetime(2021, 2, 4, 4, 35),
#  datetime.datetime(2021, 2, 4, 4, 34),
#  datetime.datetime(2021, 2, 4, 4, 33),
#  datetime.datetime(2021, 2, 4, 4, 32),
#  datetime.datetime(2021, 2, 4, 4, 31),
#  datetime.datetime(2021, 2, 4, 4, 30),
#  datetime.datetime(2021, 2, 4, 4, 29),
#  datetime.datetime(2021, 2, 4, 4, 28),
#  datetime.datetime(2021, 2, 4, 4, 27),
#  datetime.datetime(2021, 2, 4, 4, 26),
#  datetime.datetime(2021, 2, 4, 4, 25),
#  datetime.datetime(2021, 2, 4, 4, 24),
#  datetime.datetime(2021, 2, 4, 4, 23),
#  datetime.datetime(2021, 2, 4, 4, 22),
#  datetime.datetime(2021, 2, 4, 4, 21),
#  datetime.datetime(2021, 2, 4, 4, 20),
#  datetime.datetime(2021, 2, 4, 4, 19),
#  datetime.datetime(2021, 2, 4, 4, 18),
#  datetime.datetime(2021, 2, 4, 4, 17),
#  datetime.datetime(2021, 2, 4, 4, 16),
#  datetime.datetime(2021, 2, 4, 4, 15),
#  datetime.datetime(2021, 2, 4, 4, 14),
#  datetime.datetime(2021, 2, 4, 4, 13),
#  datetime.datetime(2021, 2, 4, 4, 12),
#  datetime.datetime(2021, 2, 4, 4, 11),
#  datetime.datetime(2021, 2, 4, 4, 10),
#  datetime.datetime(2021, 2, 4, 4, 9),
#  datetime.datetime(2021, 2, 4, 4, 8),
#  datetime.datetime(2021, 2, 4, 4, 7),
#  datetime.datetime(2021, 2, 4, 4, 6),
#  datetime.datetime(2021, 2, 4, 4, 5),
#  datetime.datetime(2021, 2, 4, 4, 4),
#  datetime.datetime(2021, 2, 4, 4, 3),
#  datetime.datetime(2021, 2, 4, 4, 2),
#  datetime.datetime(2021, 2, 4, 4, 1),
#  datetime.datetime(2021, 2, 4, 4, 0),
#  datetime.datetime(2021, 2, 4, 3, 59),
#  datetime.datetime(2021, 2, 4, 3, 58),
#  datetime.datetime(2021, 2, 4, 3, 57),
#  datetime.datetime(2021, 2, 4, 3, 56),
#  datetime.datetime(2021, 2, 4, 3, 55),
#  datetime.datetime(2021, 2, 4, 3, 54),
#  datetime.datetime(2021, 2, 4, 3, 53),
#  datetime.datetime(2021, 2, 4, 3, 52),
#  datetime.datetime(2021, 2, 4, 3, 51),
#  datetime.datetime(2021, 2, 4, 3, 50),
#  datetime.datetime(2021, 2, 4, 3, 49),
#  datetime.datetime(2021, 2, 4, 3, 48),
#  datetime.datetime(2021, 2, 4, 3, 47),
#  datetime.datetime(2021, 2, 4, 3, 46),
#  datetime.datetime(2021, 2, 4, 3, 45),
#  datetime.datetime(2021, 2, 4, 3, 44),
#  datetime.datetime(2021, 2, 4, 3, 43),
#  datetime.datetime(2021, 2, 4, 3, 42),
#  datetime.datetime(2021, 2, 4, 3, 41),
#  datetime.datetime(2021, 2, 4, 3, 40),
#  datetime.datetime(2021, 2, 4, 3, 39),
#  datetime.datetime(2021, 2, 4, 3, 38),
#  datetime.datetime(2021, 2, 4, 3, 37),
#  datetime.datetime(2021, 2, 4, 3, 36),
#  datetime.datetime(2021, 2, 4, 3, 35),
#  datetime.datetime(2021, 2, 4, 3, 34),
#  datetime.datetime(2021, 2, 4, 3, 33),
#  datetime.datetime(2021, 2, 4, 3, 32),
#  datetime.datetime(2021, 2, 4, 3, 31),
#  datetime.datetime(2021, 2, 4, 3, 30),
#  datetime.datetime(2021, 2, 4, 3, 29),
#  datetime.datetime(2021, 2, 4, 3, 28),
#  datetime.datetime(2021, 2, 4, 3, 27),
#  datetime.datetime(2021, 2, 4, 3, 26),
#  datetime.datetime(2021, 2, 4, 3, 25),
#  datetime.datetime(2021, 2, 4, 3, 24),
#  datetime.datetime(2021, 2, 4, 3, 23),
#  datetime.datetime(2021, 2, 4, 3, 22),
#  datetime.datetime(2021, 2, 4, 3, 21),
#  datetime.datetime(2021, 2, 4, 3, 20),
#  datetime.datetime(2021, 2, 4, 3, 19),
#  datetime.datetime(2021, 2, 4, 3, 18),
#  datetime.datetime(2021, 2, 4, 3, 17),
#  datetime.datetime(2021, 2, 4, 3, 16),
#  datetime.datetime(2021, 2, 4, 3, 15),
#  datetime.datetime(2021, 2, 4, 3, 14),
#  datetime.datetime(2021, 2, 4, 3, 13),
#  datetime.datetime(2021, 2, 4, 3, 12),
#  datetime.datetime(2021, 2, 4, 3, 11),
#  datetime.datetime(2021, 2, 4, 3, 10),
#  datetime.datetime(2021, 2, 4, 3, 9),
#  datetime.datetime(2021, 2, 4, 3, 8),
#  datetime.datetime(2021, 2, 4, 3, 7),
#  datetime.datetime(2021, 2, 4, 3, 6),
#  datetime.datetime(2021, 2, 4, 3, 5),
#  datetime.datetime(2021, 2, 4, 3, 4),
#  datetime.datetime(2021, 2, 4, 3, 3),
#  datetime.datetime(2021, 2, 4, 3, 2),
#  datetime.datetime(2021, 2, 4, 3, 1),
#  datetime.datetime(2021, 2, 4, 3, 0),
#  datetime.datetime(2021, 2, 4, 2, 59),
#  datetime.datetime(2021, 2, 4, 2, 58),
#  datetime.datetime(2021, 2, 4, 2, 57),
#  datetime.datetime(2021, 2, 4, 2, 56),
#  datetime.datetime(2021, 2, 4, 2, 55),
#  datetime.datetime(2021, 2, 4, 2, 54),
#  datetime.datetime(2021, 2, 4, 2, 53),
#  datetime.datetime(2021, 2, 4, 2, 52),
#  datetime.datetime(2021, 2, 4, 2, 51),
#  datetime.datetime(2021, 2, 4, 2, 50),
#  datetime.datetime(2021, 2, 4, 2, 49),
#  datetime.datetime(2021, 2, 4, 2, 48),
#  datetime.datetime(2021, 2, 4, 2, 47),
#  datetime.datetime(2021, 2, 4, 2, 46),
#  datetime.datetime(2021, 2, 4, 2, 45),
#  datetime.datetime(2021, 2, 4, 2, 44),
#  datetime.datetime(2021, 2, 4, 2, 43),
#  datetime.datetime(2021, 2, 4, 2, 42),
#  datetime.datetime(2021, 2, 4, 2, 41),
#  datetime.datetime(2021, 2, 4, 2, 40),
#  datetime.datetime(2021, 2, 4, 2, 39),
#  datetime.datetime(2021, 2, 4, 2, 38),
#  datetime.datetime(2021, 2, 4, 2, 37),
#  datetime.datetime(2021, 2, 4, 2, 36),
#  datetime.datetime(2021, 2, 4, 2, 35),
#  datetime.datetime(2021, 2, 4, 2, 34),
#  datetime.datetime(2021, 2, 4, 2, 33),
#  datetime.datetime(2021, 2, 4, 2, 32),
#  datetime.datetime(2021, 2, 4, 2, 31),
#  datetime.datetime(2021, 2, 4, 2, 30),
#  datetime.datetime(2021, 2, 4, 2, 29),
#  datetime.datetime(2021, 2, 4, 2, 28),
#  datetime.datetime(2021, 2, 4, 2, 27),
#  datetime.datetime(2021, 2, 4, 2, 26),
#  datetime.datetime(2021, 2, 4, 2, 25),
#  datetime.datetime(2021, 2, 4, 2, 24),
#  datetime.datetime(2021, 2, 4, 2, 23),
#  datetime.datetime(2021, 2, 4, 2, 22),
#  datetime.datetime(2021, 2, 4, 2, 21),
#  datetime.datetime(2021, 2, 4, 2, 20),
#  datetime.datetime(2021, 2, 4, 2, 19),
#  datetime.datetime(2021, 2, 4, 2, 18),
#  datetime.datetime(2021, 2, 4, 2, 17),
#  datetime.datetime(2021, 2, 4, 2, 16),
#  datetime.datetime(2021, 2, 4, 2, 15),
#  datetime.datetime(2021, 2, 4, 2, 14),
#  datetime.datetime(2021, 2, 4, 2, 13),
#  datetime.datetime(2021, 2, 4, 2, 12),
#  datetime.datetime(2021, 2, 4, 2, 11),
#  datetime.datetime(2021, 2, 4, 2, 10),
#  datetime.datetime(2021, 2, 4, 2, 9),
#  datetime.datetime(2021, 2, 4, 2, 8),
#  datetime.datetime(2021, 2, 4, 2, 7),
#  datetime.datetime(2021, 2, 4, 2, 6),
#  datetime.datetime(2021, 2, 4, 2, 5),
#  datetime.datetime(2021, 2, 4, 2, 4),
#  datetime.datetime(2021, 2, 4, 2, 3),
#  datetime.datetime(2021, 2, 4, 2, 2),
#  datetime.datetime(2021, 2, 4, 2, 1),
#  datetime.datetime(2021, 2, 4, 2, 0),
#  datetime.datetime(2021, 2, 4, 1, 59),
#  datetime.datetime(2021, 2, 4, 1, 58),
#  datetime.datetime(2021, 2, 4, 1, 57),
#  datetime.datetime(2021, 2, 4, 1, 56),
#  datetime.datetime(2021, 2, 4, 1, 55),
#  datetime.datetime(2021, 2, 4, 1, 54),
#  datetime.datetime(2021, 2, 4, 1, 53),
#  datetime.datetime(2021, 2, 4, 1, 52),
#  datetime.datetime(2021, 2, 4, 1, 51),
#  datetime.datetime(2021, 2, 4, 1, 50),
#  datetime.datetime(2021, 2, 4, 1, 49),
#  datetime.datetime(2021, 2, 4, 1, 48),
#  datetime.datetime(2021, 2, 4, 1, 47),
#  datetime.datetime(2021, 2, 4, 1, 46),
#  datetime.datetime(2021, 2, 4, 1, 45),
#  datetime.datetime(2021, 2, 4, 1, 44),
#  datetime.datetime(2021, 2, 4, 1, 43),
#  datetime.datetime(2021, 2, 4, 1, 42),
#  datetime.datetime(2021, 2, 4, 1, 41),
#  datetime.datetime(2021, 2, 4, 1, 40),
#  datetime.datetime(2021, 2, 4, 1, 39),
#  datetime.datetime(2021, 2, 4, 1, 38),
#  datetime.datetime(2021, 2, 4, 1, 37),
#  datetime.datetime(2021, 2, 4, 1, 36),
#  datetime.datetime(2021, 2, 4, 1, 35),
#  datetime.datetime(2021, 2, 4, 1, 34),
#  datetime.datetime(2021, 2, 4, 1, 33),
#  datetime.datetime(2021, 2, 4, 1, 32),
#  datetime.datetime(2021, 2, 4, 1, 31),
#  datetime.datetime(2021, 2, 4, 1, 30),
#  datetime.datetime(2021, 2, 4, 1, 29),
#  datetime.datetime(2021, 2, 4, 1, 28),
#  datetime.datetime(2021, 2, 4, 1, 27),
#  datetime.datetime(2021, 2, 4, 1, 26),
#  datetime.datetime(2021, 2, 4, 1, 25),
#  datetime.datetime(2021, 2, 4, 1, 24),
#  datetime.datetime(2021, 2, 4, 1, 23),
#  datetime.datetime(2021, 2, 4, 1, 22),
#  datetime.datetime(2021, 2, 4, 1, 21),
#  datetime.datetime(2021, 2, 4, 1, 20),
#  datetime.datetime(2021, 2, 4, 1, 19),
#  datetime.datetime(2021, 2, 4, 1, 18),
#  datetime.datetime(2021, 2, 4, 1, 17),
#  datetime.datetime(2021, 2, 4, 1, 16),
#  datetime.datetime(2021, 2, 4, 1, 15),
#  datetime.datetime(2021, 2, 4, 1, 14),
#  datetime.datetime(2021, 2, 4, 1, 13),
#  datetime.datetime(2021, 2, 4, 1, 12),
#  datetime.datetime(2021, 2, 4, 1, 11),
#  datetime.datetime(2021, 2, 4, 1, 10),
#  datetime.datetime(2021, 2, 4, 1, 9),
#  datetime.datetime(2021, 2, 4, 1, 8),
#  datetime.datetime(2021, 2, 4, 1, 7),
#  datetime.datetime(2021, 2, 4, 1, 6),
#  datetime.datetime(2021, 2, 4, 1, 5),
#  datetime.datetime(2021, 2, 4, 1, 4),
#  datetime.datetime(2021, 2, 4, 1, 3),
#  datetime.datetime(2021, 2, 4, 1, 2),
#  datetime.datetime(2021, 2, 4, 1, 1),
#  datetime.datetime(2021, 2, 4, 1, 0),
#  datetime.datetime(2021, 2, 4, 0, 59),
#  datetime.datetime(2021, 2, 4, 0, 58),
#  datetime.datetime(2021, 2, 4, 0, 57),
#  datetime.datetime(2021, 2, 4, 0, 56),
#  datetime.datetime(2021, 2, 4, 0, 55),
#  datetime.datetime(2021, 2, 4, 0, 54),
#  datetime.datetime(2021, 2, 4, 0, 53),
#  datetime.datetime(2021, 2, 4, 0, 52),
#  datetime.datetime(2021, 2, 4, 0, 51),
#  datetime.datetime(2021, 2, 4, 0, 50),
#  datetime.datetime(2021, 2, 4, 0, 49),
#  datetime.datetime(2021, 2, 4, 0, 48),
#  datetime.datetime(2021, 2, 4, 0, 47),
#  datetime.datetime(2021, 2, 4, 0, 46),
#  datetime.datetime(2021, 2, 4, 0, 45),
#  datetime.datetime(2021, 2, 4, 0, 44),
#  datetime.datetime(2021, 2, 4, 0, 43),
#  datetime.datetime(2021, 2, 4, 0, 42),
#  datetime.datetime(2021, 2, 4, 0, 41),
#  datetime.datetime(2021, 2, 4, 0, 40),
#  datetime.datetime(2021, 2, 4, 0, 39),
#  datetime.datetime(2021, 2, 4, 0, 38),
#  datetime.datetime(2021, 2, 4, 0, 37),
#  datetime.datetime(2021, 2, 4, 0, 36),
#  datetime.datetime(2021, 2, 4, 0, 35),
#  datetime.datetime(2021, 2, 4, 0, 34),
#  datetime.datetime(2021, 2, 4, 0, 33),
#  datetime.datetime(2021, 2, 4, 0, 32),
#  datetime.datetime(2021, 2, 4, 0, 31),
#  datetime.datetime(2021, 2, 4, 0, 30),
#  datetime.datetime(2021, 2, 4, 0, 29),
#  datetime.datetime(2021, 2, 4, 0, 28),
#  datetime.datetime(2021, 2, 4, 0, 27),
#  datetime.datetime(2021, 2, 4, 0, 26),
#  datetime.datetime(2021, 2, 4, 0, 25),
#  datetime.datetime(2021, 2, 4, 0, 24),
#  datetime.datetime(2021, 2, 4, 0, 23),
#  datetime.datetime(2021, 2, 4, 0, 22),
#  datetime.datetime(2021, 2, 4, 0, 21),
#  datetime.datetime(2021, 2, 4, 0, 20),
#  datetime.datetime(2021, 2, 4, 0, 19),
#  datetime.datetime(2021, 2, 4, 0, 18),
#  datetime.datetime(2021, 2, 4, 0, 17),
#  datetime.datetime(2021, 2, 4, 0, 16),
#  datetime.datetime(2021, 2, 4, 0, 15),
#  datetime.datetime(2021, 2, 4, 0, 14),
#  datetime.datetime(2021, 2, 4, 0, 13),
#  datetime.datetime(2021, 2, 4, 0, 12),
#  datetime.datetime(2021, 2, 4, 0, 11),
#  datetime.datetime(2021, 2, 4, 0, 10),
#  datetime.datetime(2021, 2, 4, 0, 9),
#  datetime.datetime(2021, 2, 4, 0, 8),
#  datetime.datetime(2021, 2, 4, 0, 7),
#  datetime.datetime(2021, 2, 4, 0, 6),
#  datetime.datetime(2021, 2, 4, 0, 5),
#  datetime.datetime(2021, 2, 4, 0, 4),
#  datetime.datetime(2021, 2, 4, 0, 3),
#  datetime.datetime(2021, 2, 4, 0, 2),
#  datetime.datetime(2021, 2, 4, 0, 1),
#  datetime.datetime(2021, 2, 4, 0, 0),
#  datetime.datetime(2021, 2, 3, 23, 59),
#  datetime.datetime(2021, 2, 3, 23, 58),
#  datetime.datetime(2021, 2, 3, 23, 57),
#  datetime.datetime(2021, 2, 3, 23, 56),
#  datetime.datetime(2021, 2, 3, 23, 55),
#  datetime.datetime(2021, 2, 3, 23, 54),
#  datetime.datetime(2021, 2, 3, 23, 53),
#  datetime.datetime(2021, 2, 3, 23, 52),
#  datetime.datetime(2021, 2, 3, 23, 51),
#  datetime.datetime(2021, 2, 3, 23, 50),
#  datetime.datetime(2021, 2, 3, 23, 49),
#  datetime.datetime(2021, 2, 3, 23, 48),
#  datetime.datetime(2021, 2, 3, 23, 47),
#  datetime.datetime(2021, 2, 3, 23, 46),
#  datetime.datetime(2021, 2, 3, 23, 45),
#  datetime.datetime(2021, 2, 3, 23, 44),
#  datetime.datetime(2021, 2, 3, 23, 43),
#  datetime.datetime(2021, 2, 3, 23, 42),
#  datetime.datetime(2021, 2, 3, 23, 41),
#  datetime.datetime(2021, 2, 3, 23, 40),
#  datetime.datetime(2021, 2, 3, 23, 39),
#  datetime.datetime(2021, 2, 3, 23, 38),
#  datetime.datetime(2021, 2, 3, 23, 37),
#  datetime.datetime(2021, 2, 3, 23, 36),
#  datetime.datetime(2021, 2, 3, 23, 35),
#  datetime.datetime(2021, 2, 3, 23, 34),
#  datetime.datetime(2021, 2, 3, 23, 33),
#  datetime.datetime(2021, 2, 3, 23, 32),
#  datetime.datetime(2021, 2, 3, 23, 31),
#  datetime.datetime(2021, 2, 3, 23, 30),
#  datetime.datetime(2021, 2, 3, 23, 29),
#  datetime.datetime(2021, 2, 3, 23, 28),
#  datetime.datetime(2021, 2, 3, 23, 27),
#  datetime.datetime(2021, 2, 3, 23, 26),
#  datetime.datetime(2021, 2, 3, 23, 25),
#  datetime.datetime(2021, 2, 3, 23, 24),
#  datetime.datetime(2021, 2, 3, 23, 23),
#  datetime.datetime(2021, 2, 3, 23, 22),
#  datetime.datetime(2021, 2, 3, 23, 21),
#  datetime.datetime(2021, 2, 3, 23, 20),
#  datetime.datetime(2021, 2, 3, 23, 19),
#  datetime.datetime(2021, 2, 3, 23, 18),
#  datetime.datetime(2021, 2, 3, 23, 17),
#  datetime.datetime(2021, 2, 3, 23, 16),
#  datetime.datetime(2021, 2, 3, 23, 15),
#  datetime.datetime(2021, 2, 3, 23, 14),
#  datetime.datetime(2021, 2, 3, 23, 13),
#  datetime.datetime(2021, 2, 3, 23, 12),
#  datetime.datetime(2021, 2, 3, 23, 11),
#  datetime.datetime(2021, 2, 3, 23, 10),
#  datetime.datetime(2021, 2, 3, 23, 9),
#  datetime.datetime(2021, 2, 3, 23, 8),
#  datetime.datetime(2021, 2, 3, 23, 7),
#  datetime.datetime(2021, 2, 3, 23, 6),
#  datetime.datetime(2021, 2, 3, 23, 5),
#  datetime.datetime(2021, 2, 3, 23, 4),
#  datetime.datetime(2021, 2, 3, 23, 3),
#  datetime.datetime(2021, 2, 3, 23, 2),
#  datetime.datetime(2021, 2, 3, 23, 1),
#  datetime.datetime(2021, 2, 3, 23, 0),
#  datetime.datetime(2021, 2, 3, 22, 59),
#  datetime.datetime(2021, 2, 3, 22, 58),
#  datetime.datetime(2021, 2, 3, 22, 57),
#  datetime.datetime(2021, 2, 3, 22, 56),
#  datetime.datetime(2021, 2, 3, 22, 55),
#  datetime.datetime(2021, 2, 3, 22, 54),
#  datetime.datetime(2021, 2, 3, 22, 53),
#  datetime.datetime(2021, 2, 3, 22, 52),
#  datetime.datetime(2021, 2, 3, 22, 51),
#  datetime.datetime(2021, 2, 3, 22, 50),
#  datetime.datetime(2021, 2, 3, 22, 49),
#  datetime.datetime(2021, 2, 3, 22, 48),
#  datetime.datetime(2021, 2, 3, 22, 47),
#  datetime.datetime(2021, 2, 3, 22, 46),
#  datetime.datetime(2021, 2, 3, 22, 45),
#  datetime.datetime(2021, 2, 3, 22, 44),
#  datetime.datetime(2021, 2, 3, 22, 43),
#  datetime.datetime(2021, 2, 3, 22, 42),
#  datetime.datetime(2021, 2, 3, 22, 41),
#  datetime.datetime(2021, 2, 3, 22, 40),
#  datetime.datetime(2021, 2, 3, 22, 39),
#  datetime.datetime(2021, 2, 3, 22, 38),
#  datetime.datetime(2021, 2, 3, 22, 37),
#  datetime.datetime(2021, 2, 3, 22, 36),
#  datetime.datetime(2021, 2, 3, 22, 35),
#  datetime.datetime(2021, 2, 3, 22, 34),
#  datetime.datetime(2021, 2, 3, 22, 33),
#  datetime.datetime(2021, 2, 3, 22, 32),
#  datetime.datetime(2021, 2, 3, 22, 31),
#  datetime.datetime(2021, 2, 3, 22, 30),
#  datetime.datetime(2021, 2, 3, 22, 29),
#  datetime.datetime(2021, 2, 3, 22, 28),
#  datetime.datetime(2021, 2, 3, 22, 27),
#  datetime.datetime(2021, 2, 3, 22, 26),
#  datetime.datetime(2021, 2, 3, 22, 25),
#  datetime.datetime(2021, 2, 3, 22, 24),
#  datetime.datetime(2021, 2, 3, 22, 23),
#  datetime.datetime(2021, 2, 3, 22, 22),
#  datetime.datetime(2021, 2, 3, 22, 21),
#  datetime.datetime(2021, 2, 3, 22, 20),
#  datetime.datetime(2021, 2, 3, 22, 19),
#  datetime.datetime(2021, 2, 3, 22, 18),
#  datetime.datetime(2021, 2, 3, 22, 17),
#  datetime.datetime(2021, 2, 3, 22, 16),
#  datetime.datetime(2021, 2, 3, 22, 15),
#  datetime.datetime(2021, 2, 3, 22, 14),
#  datetime.datetime(2021, 2, 3, 22, 13),
#  datetime.datetime(2021, 2, 3, 22, 12),
#  datetime.datetime(2021, 2, 3, 22, 11),
#  datetime.datetime(2021, 2, 3, 22, 10),
#  datetime.datetime(2021, 2, 3, 22, 9),
#  datetime.datetime(2021, 2, 3, 22, 8),
#  datetime.datetime(2021, 2, 3, 22, 7),
#  datetime.datetime(2021, 2, 3, 22, 6),
#  datetime.datetime(2021, 2, 3, 22, 5),
#  datetime.datetime(2021, 2, 3, 22, 4),
#  datetime.datetime(2021, 2, 3, 22, 3),
#  datetime.datetime(2021, 2, 3, 22, 2),
#  datetime.datetime(2021, 2, 3, 22, 1),
#  datetime.datetime(2021, 2, 3, 22, 0),
#  datetime.datetime(2021, 2, 3, 21, 59),
#  datetime.datetime(2021, 2, 3, 21, 58),
#  datetime.datetime(2021, 2, 3, 21, 57),
#  datetime.datetime(2021, 2, 3, 21, 56),
#  datetime.datetime(2021, 2, 3, 21, 55),
#  datetime.datetime(2021, 2, 3, 21, 54),
#  datetime.datetime(2021, 2, 3, 21, 53),
#  datetime.datetime(2021, 2, 3, 21, 52),
#  datetime.datetime(2021, 2, 3, 21, 51),
#  datetime.datetime(2021, 2, 3, 21, 50),
#  datetime.datetime(2021, 2, 3, 21, 49),
#  datetime.datetime(2021, 2, 3, 21, 48),
#  datetime.datetime(2021, 2, 3, 21, 47),
#  datetime.datetime(2021, 2, 3, 21, 46),
#  datetime.datetime(2021, 2, 3, 21, 45),
#  datetime.datetime(2021, 2, 3, 21, 44),
#  datetime.datetime(2021, 2, 3, 21, 43),
#  datetime.datetime(2021, 2, 3, 21, 42),
#  datetime.datetime(2021, 2, 3, 21, 41),
#  datetime.datetime(2021, 2, 3, 21, 40),
#  datetime.datetime(2021, 2, 3, 21, 39),
#  datetime.datetime(2021, 2, 3, 21, 38),
#  datetime.datetime(2021, 2, 3, 21, 37),
#  datetime.datetime(2021, 2, 3, 21, 36),
#  datetime.datetime(2021, 2, 3, 21, 35),
#  datetime.datetime(2021, 2, 3, 21, 34),
#  datetime.datetime(2021, 2, 3, 21, 33),
#  datetime.datetime(2021, 2, 3, 21, 32),
#  datetime.datetime(2021, 2, 3, 21, 31),
#  datetime.datetime(2021, 2, 3, 21, 30),
#  datetime.datetime(2021, 2, 3, 21, 29),
#  datetime.datetime(2021, 2, 3, 21, 28),
#  datetime.datetime(2021, 2, 3, 21, 27),
#  datetime.datetime(2021, 2, 3, 21, 26),
#  datetime.datetime(2021, 2, 3, 21, 25),
#  datetime.datetime(2021, 2, 3, 21, 24),
#  datetime.datetime(2021, 2, 3, 21, 23),
#  datetime.datetime(2021, 2, 3, 21, 22),
#  datetime.datetime(2021, 2, 3, 21, 21),
#  datetime.datetime(2021, 2, 3, 21, 20),
#  datetime.datetime(2021, 2, 3, 21, 19),
#  datetime.datetime(2021, 2, 3, 21, 18),
#  datetime.datetime(2021, 2, 3, 21, 17),
#  datetime.datetime(2021, 2, 3, 21, 16),
#  datetime.datetime(2021, 2, 3, 21, 15),
#  datetime.datetime(2021, 2, 3, 21, 14),
#  datetime.datetime(2021, 2, 3, 21, 13),
#  datetime.datetime(2021, 2, 3, 21, 12),
#  datetime.datetime(2021, 2, 3, 21, 11),
#  datetime.datetime(2021, 2, 3, 21, 10),
#  datetime.datetime(2021, 2, 3, 21, 9),
#  datetime.datetime(2021, 2, 3, 21, 8),
#  datetime.datetime(2021, 2, 3, 21, 7),
#  datetime.datetime(2021, 2, 3, 21, 6),
#  datetime.datetime(2021, 2, 3, 21, 5),
#  datetime.datetime(2021, 2, 3, 21, 4),
#  datetime.datetime(2021, 2, 3, 21, 3),
#  datetime.datetime(2021, 2, 3, 21, 2),
#  datetime.datetime(2021, 2, 3, 21, 1),
#  datetime.datetime(2021, 2, 3, 21, 0),
#  datetime.datetime(2021, 2, 3, 20, 59),
#  datetime.datetime(2021, 2, 3, 20, 58),
#  datetime.datetime(2021, 2, 3, 20, 57),
#  datetime.datetime(2021, 2, 3, 20, 56),
#  datetime.datetime(2021, 2, 3, 20, 55),
#  datetime.datetime(2021, 2, 3, 20, 54),
#  datetime.datetime(2021, 2, 3, 20, 53),
#  datetime.datetime(2021, 2, 3, 20, 52),
#  datetime.datetime(2021, 2, 3, 20, 51),
#  datetime.datetime(2021, 2, 3, 20, 50),
#  datetime.datetime(2021, 2, 3, 20, 49),
#  datetime.datetime(2021, 2, 3, 20, 48),
#  datetime.datetime(2021, 2, 3, 20, 47),
#  datetime.datetime(2021, 2, 3, 20, 46),
#  datetime.datetime(2021, 2, 3, 20, 45),
#  datetime.datetime(2021, 2, 3, 20, 44),
#  datetime.datetime(2021, 2, 3, 20, 43),
#  datetime.datetime(2021, 2, 3, 20, 42),
#  datetime.datetime(2021, 2, 3, 20, 41),
#  datetime.datetime(2021, 2, 3, 20, 40),
#  datetime.datetime(2021, 2, 3, 20, 39),
#  datetime.datetime(2021, 2, 3, 20, 38),
#  datetime.datetime(2021, 2, 3, 20, 37),
#  datetime.datetime(2021, 2, 3, 20, 36),
#  datetime.datetime(2021, 2, 3, 20, 35),
#  datetime.datetime(2021, 2, 3, 20, 34),
#  datetime.datetime(2021, 2, 3, 20, 33),
#  datetime.datetime(2021, 2, 3, 20, 32),
#  datetime.datetime(2021, 2, 3, 20, 31),
#  datetime.datetime(2021, 2, 3, 20, 30),
#  datetime.datetime(2021, 2, 3, 20, 29),
#  datetime.datetime(2021, 2, 3, 20, 28),
#  datetime.datetime(2021, 2, 3, 20, 27),
#  datetime.datetime(2021, 2, 3, 20, 26),
#  datetime.datetime(2021, 2, 3, 20, 25),
#  datetime.datetime(2021, 2, 3, 20, 24),
#  datetime.datetime(2021, 2, 3, 20, 23),
#  datetime.datetime(2021, 2, 3, 20, 22),
#  datetime.datetime(2021, 2, 3, 20, 21),
#  datetime.datetime(2021, 2, 3, 20, 20),
#  datetime.datetime(2021, 2, 3, 20, 19),
#  datetime.datetime(2021, 2, 3, 20, 18),
#  datetime.datetime(2021, 2, 3, 20, 17),
#  datetime.datetime(2021, 2, 3, 20, 16),
#  datetime.datetime(2021, 2, 3, 20, 15),
#  datetime.datetime(2021, 2, 3, 20, 14),
#  datetime.datetime(2021, 2, 3, 20, 13),
#  datetime.datetime(2021, 2, 3, 20, 12),
#  datetime.datetime(2021, 2, 3, 20, 11),
#  datetime.datetime(2021, 2, 3, 20, 10),
#  datetime.datetime(2021, 2, 3, 20, 9),
#  datetime.datetime(2021, 2, 3, 20, 8),
#  datetime.datetime(2021, 2, 3, 20, 7),
#  datetime.datetime(2021, 2, 3, 20, 6),
#  datetime.datetime(2021, 2, 3, 20, 5),
#  datetime.datetime(2021, 2, 3, 20, 4),
#  datetime.datetime(2021, 2, 3, 20, 3),
#  datetime.datetime(2021, 2, 3, 20, 2),
#  datetime.datetime(2021, 2, 3, 20, 1),
#  datetime.datetime(2021, 2, 3, 20, 0),
#  datetime.datetime(2021, 2, 3, 19, 59),
#  datetime.datetime(2021, 2, 3, 19, 58),
#  datetime.datetime(2021, 2, 3, 19, 57),
#  datetime.datetime(2021, 2, 3, 19, 56),
#  datetime.datetime(2021, 2, 3, 19, 55),
#  datetime.datetime(2021, 2, 3, 19, 54),
#  datetime.datetime(2021, 2, 3, 19, 53),
#  datetime.datetime(2021, 2, 3, 19, 52),
#  datetime.datetime(2021, 2, 3, 19, 51),
#  datetime.datetime(2021, 2, 3, 19, 50),
#  datetime.datetime(2021, 2, 3, 19, 49),
#  datetime.datetime(2021, 2, 3, 19, 48),
#  datetime.datetime(2021, 2, 3, 19, 47),
#  datetime.datetime(2021, 2, 3, 19, 46),
#  datetime.datetime(2021, 2, 3, 19, 45),
#  datetime.datetime(2021, 2, 3, 19, 44),
#  datetime.datetime(2021, 2, 3, 19, 43),
#  datetime.datetime(2021, 2, 3, 19, 42),
#  datetime.datetime(2021, 2, 3, 19, 41),
#  datetime.datetime(2021, 2, 3, 19, 40),
#  datetime.datetime(2021, 2, 3, 19, 39),
#  datetime.datetime(2021, 2, 3, 19, 38),
#  datetime.datetime(2021, 2, 3, 19, 37),
#  datetime.datetime(2021, 2, 3, 19, 36),
#  datetime.datetime(2021, 2, 3, 19, 35),
#  datetime.datetime(2021, 2, 3, 19, 34),
#  datetime.datetime(2021, 2, 3, 19, 33),
#  datetime.datetime(2021, 2, 3, 19, 32),
#  datetime.datetime(2021, 2, 3, 19, 31),
#  datetime.datetime(2021, 2, 3, 19, 30),
#  datetime.datetime(2021, 2, 3, 19, 29),
#  datetime.datetime(2021, 2, 3, 19, 28),
#  datetime.datetime(2021, 2, 3, 19, 27),
#  datetime.datetime(2021, 2, 3, 19, 26),
#  datetime.datetime(2021, 2, 3, 19, 25),
#  datetime.datetime(2021, 2, 3, 19, 24),
#  datetime.datetime(2021, 2, 3, 19, 23),
#  datetime.datetime(2021, 2, 3, 19, 22),
#  datetime.datetime(2021, 2, 3, 19, 21),
#  datetime.datetime(2021, 2, 3, 19, 20),
#  datetime.datetime(2021, 2, 3, 19, 19),
#  datetime.datetime(2021, 2, 3, 19, 18),
#  datetime.datetime(2021, 2, 3, 19, 17),
#  datetime.datetime(2021, 2, 3, 19, 16),
#  datetime.datetime(2021, 2, 3, 19, 15),
#  datetime.datetime(2021, 2, 3, 19, 14),
#  datetime.datetime(2021, 2, 3, 19, 13),
#  datetime.datetime(2021, 2, 3, 19, 12),
#  datetime.datetime(2021, 2, 3, 19, 11),
#  datetime.datetime(2021, 2, 3, 19, 10),
#  datetime.datetime(2021, 2, 3, 19, 9),
#  datetime.datetime(2021, 2, 3, 19, 8),
#  datetime.datetime(2021, 2, 3, 19, 7),
#  datetime.datetime(2021, 2, 3, 19, 6),
#  datetime.datetime(2021, 2, 3, 19, 5),
#  datetime.datetime(2021, 2, 3, 19, 4),
#  datetime.datetime(2021, 2, 3, 19, 3),
#  datetime.datetime(2021, 2, 3, 19, 2),
#  datetime.datetime(2021, 2, 3, 19, 1),
#  datetime.datetime(2021, 2, 3, 19, 0),
#  datetime.datetime(2021, 2, 3, 18, 59),
#  datetime.datetime(2021, 2, 3, 18, 58),
#  datetime.datetime(2021, 2, 3, 18, 57),
#  datetime.datetime(2021, 2, 3, 18, 56),
#  datetime.datetime(2021, 2, 3, 18, 55),
#  datetime.datetime(2021, 2, 3, 18, 54),
#  datetime.datetime(2021, 2, 3, 18, 53),
#  datetime.datetime(2021, 2, 3, 18, 52),
#  datetime.datetime(2021, 2, 3, 18, 51),
#  datetime.datetime(2021, 2, 3, 18, 50),
#  datetime.datetime(2021, 2, 3, 18, 49),
#  datetime.datetime(2021, 2, 3, 18, 48),
#  datetime.datetime(2021, 2, 3, 18, 47),
#  datetime.datetime(2021, 2, 3, 18, 46),
#  datetime.datetime(2021, 2, 3, 18, 45),
#  datetime.datetime(2021, 2, 3, 18, 44),
#  datetime.datetime(2021, 2, 3, 18, 43),
#  datetime.datetime(2021, 2, 3, 18, 42),
#  datetime.datetime(2021, 2, 3, 18, 41),
#  datetime.datetime(2021, 2, 3, 18, 40),
#  datetime.datetime(2021, 2, 3, 18, 39),
#  datetime.datetime(2021, 2, 3, 18, 38),
#  datetime.datetime(2021, 2, 3, 18, 37),
#  datetime.datetime(2021, 2, 3, 18, 36),
#  datetime.datetime(2021, 2, 3, 18, 35),
#  datetime.datetime(2021, 2, 3, 18, 34),
#  datetime.datetime(2021, 2, 3, 18, 33),
#  datetime.datetime(2021, 2, 3, 18, 32),
#  datetime.datetime(2021, 2, 3, 18, 31),
#  datetime.datetime(2021, 2, 3, 18, 30),
#  datetime.datetime(2021, 2, 3, 18, 29),
#  datetime.datetime(2021, 2, 3, 18, 28),
#  datetime.datetime(2021, 2, 3, 18, 27),
#  datetime.datetime(2021, 2, 3, 18, 26),
#  datetime.datetime(2021, 2, 3, 18, 25),
#  datetime.datetime(2021, 2, 3, 18, 24),
#  datetime.datetime(2021, 2, 3, 18, 23),
#  datetime.datetime(2021, 2, 3, 18, 22),
#  datetime.datetime(2021, 2, 3, 18, 21),
#  datetime.datetime(2021, 2, 3, 18, 20),
#  datetime.datetime(2021, 2, 3, 18, 19),
#  datetime.datetime(2021, 2, 3, 18, 18),
#  datetime.datetime(2021, 2, 3, 18, 17),
#  datetime.datetime(2021, 2, 3, 18, 16),
#  datetime.datetime(2021, 2, 3, 18, 15),
#  datetime.datetime(2021, 2, 3, 18, 14),
#  datetime.datetime(2021, 2, 3, 18, 13),
#  datetime.datetime(2021, 2, 3, 18, 12),
#  datetime.datetime(2021, 2, 3, 18, 11),
#  datetime.datetime(2021, 2, 3, 18, 10),
#  datetime.datetime(2021, 2, 3, 18, 9),
#  datetime.datetime(2021, 2, 3, 18, 8),
#  datetime.datetime(2021, 2, 3, 18, 7),
#  datetime.datetime(2021, 2, 3, 18, 6),
#  datetime.datetime(2021, 2, 3, 18, 5),
#  datetime.datetime(2021, 2, 3, 18, 4),
#  datetime.datetime(2021, 2, 3, 18, 3),
#  datetime.datetime(2021, 2, 3, 18, 2),
#  datetime.datetime(2021, 2, 3, 18, 1),
#  datetime.datetime(2021, 2, 3, 18, 0),
#  datetime.datetime(2021, 2, 3, 17, 59),
#  datetime.datetime(2021, 2, 3, 17, 58),
#  datetime.datetime(2021, 2, 3, 17, 57),
#  datetime.datetime(2021, 2, 3, 17, 56),
#  datetime.datetime(2021, 2, 3, 17, 55),
#  datetime.datetime(2021, 2, 3, 17, 54),
#  datetime.datetime(2021, 2, 3, 17, 53),
#  datetime.datetime(2021, 2, 3, 17, 52),
#  datetime.datetime(2021, 2, 3, 17, 51),
#  datetime.datetime(2021, 2, 3, 17, 50),
#  datetime.datetime(2021, 2, 3, 17, 49),
#  datetime.datetime(2021, 2, 3, 17, 48),
#  datetime.datetime(2021, 2, 3, 17, 47),
#  datetime.datetime(2021, 2, 3, 17, 46),
#  datetime.datetime(2021, 2, 3, 17, 45),
#  datetime.datetime(2021, 2, 3, 17, 44),
#  datetime.datetime(2021, 2, 3, 17, 43),
#  datetime.datetime(2021, 2, 3, 17, 42),
#  datetime.datetime(2021, 2, 3, 17, 41),
#  datetime.datetime(2021, 2, 3, 17, 40),
#  datetime.datetime(2021, 2, 3, 17, 39),
#  datetime.datetime(2021, 2, 3, 17, 38),
#  datetime.datetime(2021, 2, 3, 17, 37),
#  datetime.datetime(2021, 2, 3, 17, 36),
#  datetime.datetime(2021, 2, 3, 17, 35),
#  datetime.datetime(2021, 2, 3, 17, 34),
#  datetime.datetime(2021, 2, 3, 17, 33),
#  datetime.datetime(2021, 2, 3, 17, 32),
#  datetime.datetime(2021, 2, 3, 17, 31),
#  datetime.datetime(2021, 2, 3, 17, 30),
#  datetime.datetime(2021, 2, 3, 17, 29),
#  datetime.datetime(2021, 2, 3, 17, 28),
#  datetime.datetime(2021, 2, 3, 17, 27),
#  datetime.datetime(2021, 2, 3, 17, 26),
#  datetime.datetime(2021, 2, 3, 17, 25),
#  datetime.datetime(2021, 2, 3, 17, 24),
#  datetime.datetime(2021, 2, 3, 17, 23),
#  datetime.datetime(2021, 2, 3, 17, 22),
#  datetime.datetime(2021, 2, 3, 17, 21),
#  datetime.datetime(2021, 2, 3, 17, 20),
#  datetime.datetime(2021, 2, 3, 17, 19),
#  datetime.datetime(2021, 2, 3, 17, 18),
#  datetime.datetime(2021, 2, 3, 17, 17),
#  datetime.datetime(2021, 2, 3, 17, 16),
#  datetime.datetime(2021, 2, 3, 17, 15),
#  datetime.datetime(2021, 2, 3, 17, 14),
#  datetime.datetime(2021, 2, 3, 17, 13),
#  datetime.datetime(2021, 2, 3, 17, 12),
#  datetime.datetime(2021, 2, 3, 17, 11),
#  datetime.datetime(2021, 2, 3, 17, 10),
#  datetime.datetime(2021, 2, 3, 17, 9),
#  datetime.datetime(2021, 2, 3, 17, 8),
#  datetime.datetime(2021, 2, 3, 17, 7),
#  datetime.datetime(2021, 2, 3, 17, 6),
#  datetime.datetime(2021, 2, 3, 17, 5),
#  datetime.datetime(2021, 2, 3, 17, 4),
#  datetime.datetime(2021, 2, 3, 17, 3),
#  datetime.datetime(2021, 2, 3, 17, 2),
#  datetime.datetime(2021, 2, 3, 17, 1),
#  datetime.datetime(2021, 2, 3, 17, 0),
#  datetime.datetime(2021, 2, 3, 16, 59),
#  datetime.datetime(2021, 2, 3, 16, 58),
#  datetime.datetime(2021, 2, 3, 16, 57),
#  datetime.datetime(2021, 2, 3, 16, 56),
#  datetime.datetime(2021, 2, 3, 16, 55),
#  datetime.datetime(2021, 2, 3, 16, 54),
#  datetime.datetime(2021, 2, 3, 16, 53),
#  datetime.datetime(2021, 2, 3, 16, 52),
#  datetime.datetime(2021, 2, 3, 16, 51),
#  datetime.datetime(2021, 2, 3, 16, 50),
#  datetime.datetime(2021, 2, 3, 16, 49),
#  datetime.datetime(2021, 2, 3, 16, 48),
#  datetime.datetime(2021, 2, 3, 16, 47),
#  datetime.datetime(2021, 2, 3, 16, 46),
#  datetime.datetime(2021, 2, 3, 16, 45),
#  datetime.datetime(2021, 2, 3, 16, 44),
#  datetime.datetime(2021, 2, 3, 16, 43),
#  datetime.datetime(2021, 2, 3, 16, 42),
#  datetime.datetime(2021, 2, 3, 16, 41),
#  datetime.datetime(2021, 2, 3, 16, 40),
#  datetime.datetime(2021, 2, 3, 16, 39),
#  datetime.datetime(2021, 2, 3, 16, 38),
#  datetime.datetime(2021, 2, 3, 16, 37),
#  datetime.datetime(2021, 2, 3, 16, 36),
#  datetime.datetime(2021, 2, 3, 16, 35),
#  datetime.datetime(2021, 2, 3, 16, 34),
#  datetime.datetime(2021, 2, 3, 16, 33),
#  datetime.datetime(2021, 2, 3, 16, 32),
#  datetime.datetime(2021, 2, 3, 16, 31),
#  datetime.datetime(2021, 2, 3, 16, 30),
#  datetime.datetime(2021, 2, 3, 16, 29),
#  datetime.datetime(2021, 2, 3, 16, 28),
#  datetime.datetime(2021, 2, 3, 16, 27),
#  datetime.datetime(2021, 2, 3, 16, 26),
#  datetime.datetime(2021, 2, 3, 16, 25),
#  datetime.datetime(2021, 2, 3, 16, 24),
#  datetime.datetime(2021, 2, 3, 16, 23),
#  datetime.datetime(2021, 2, 3, 16, 22),
#  datetime.datetime(2021, 2, 3, 16, 21),
#  datetime.datetime(2021, 2, 3, 16, 20),
#  datetime.datetime(2021, 2, 3, 16, 19),
#  datetime.datetime(2021, 2, 3, 16, 18),
#  datetime.datetime(2021, 2, 3, 16, 17),
#  datetime.datetime(2021, 2, 3, 16, 16),
#  datetime.datetime(2021, 2, 3, 16, 15),
#  datetime.datetime(2021, 2, 3, 16, 14),
#  datetime.datetime(2021, 2, 3, 16, 13),
#  datetime.datetime(2021, 2, 3, 16, 12),
#  datetime.datetime(2021, 2, 3, 16, 11),
#  datetime.datetime(2021, 2, 3, 16, 10),
#  datetime.datetime(2021, 2, 3, 16, 9),
#  datetime.datetime(2021, 2, 3, 16, 8),
#  datetime.datetime(2021, 2, 3, 16, 7),
#  datetime.datetime(2021, 2, 3, 16, 6),
#  datetime.datetime(2021, 2, 3, 16, 5),
#  datetime.datetime(2021, 2, 3, 16, 4),
#  datetime.datetime(2021, 2, 3, 16, 3),
#  datetime.datetime(2021, 2, 3, 16, 2),
#  datetime.datetime(2021, 2, 3, 16, 1),
#  datetime.datetime(2021, 2, 3, 16, 0),
#  datetime.datetime(2021, 2, 3, 15, 59),
#  datetime.datetime(2021, 2, 3, 15, 58),
#  datetime.datetime(2021, 2, 3, 15, 57),
#  datetime.datetime(2021, 2, 3, 15, 56),
#  datetime.datetime(2021, 2, 3, 15, 55),
#  datetime.datetime(2021, 2, 3, 15, 54),
#  datetime.datetime(2021, 2, 3, 15, 53),
#  datetime.datetime(2021, 2, 3, 15, 52),
#  datetime.datetime(2021, 2, 3, 15, 51),
#  datetime.datetime(2021, 2, 3, 15, 50),
#  datetime.datetime(2021, 2, 3, 15, 49),
#  datetime.datetime(2021, 2, 3, 15, 48),
#  datetime.datetime(2021, 2, 3, 15, 47),
#  datetime.datetime(2021, 2, 3, 15, 46),
#  datetime.datetime(2021, 2, 3, 15, 45),
#  datetime.datetime(2021, 2, 3, 15, 44),
#  datetime.datetime(2021, 2, 3, 15, 43),
#  datetime.datetime(2021, 2, 3, 15, 42),
#  datetime.datetime(2021, 2, 3, 15, 41),
#  datetime.datetime(2021, 2, 3, 15, 40),
#  datetime.datetime(2021, 2, 3, 15, 39),
#  datetime.datetime(2021, 2, 3, 15, 38),
#  datetime.datetime(2021, 2, 3, 15, 37),
#  datetime.datetime(2021, 2, 3, 15, 36),
#  datetime.datetime(2021, 2, 3, 15, 35),
#  datetime.datetime(2021, 2, 3, 15, 34),
#  datetime.datetime(2021, 2, 3, 15, 33),
#  datetime.datetime(2021, 2, 3, 15, 32),
#  datetime.datetime(2021, 2, 3, 15, 31),
#  datetime.datetime(2021, 2, 3, 15, 30),
#  datetime.datetime(2021, 2, 3, 15, 29),
#  datetime.datetime(2021, 2, 3, 15, 28),
#  datetime.datetime(2021, 2, 3, 15, 27),
#  datetime.datetime(2021, 2, 3, 15, 26),
#  datetime.datetime(2021, 2, 3, 15, 25),
#  datetime.datetime(2021, 2, 3, 15, 24),
#  datetime.datetime(2021, 2, 3, 15, 23),
#  datetime.datetime(2021, 2, 3, 15, 22),
#  datetime.datetime(2021, 2, 3, 15, 21),
#  datetime.datetime(2021, 2, 3, 15, 20),
#  datetime.datetime(2021, 2, 3, 15, 19),
#  datetime.datetime(2021, 2, 3, 15, 18),
#  datetime.datetime(2021, 2, 3, 15, 17),
#  datetime.datetime(2021, 2, 3, 15, 16),
#  datetime.datetime(2021, 2, 3, 15, 15),
#  datetime.datetime(2021, 2, 3, 15, 14),
#  datetime.datetime(2021, 2, 3, 15, 13),
#  datetime.datetime(2021, 2, 3, 15, 12),
#  datetime.datetime(2021, 2, 3, 15, 11),
#  datetime.datetime(2021, 2, 3, 15, 10),
#  datetime.datetime(2021, 2, 3, 15, 9),
#  datetime.datetime(2021, 2, 3, 15, 8),
#  datetime.datetime(2021, 2, 3, 15, 7),
#  datetime.datetime(2021, 2, 3, 15, 6),
#  datetime.datetime(2021, 2, 3, 15, 5),
#  datetime.datetime(2021, 2, 3, 15, 4),
#  datetime.datetime(2021, 2, 3, 15, 3),
#  datetime.datetime(2021, 2, 3, 15, 2),
#  datetime.datetime(2021, 2, 3, 15, 1),
#  datetime.datetime(2021, 2, 3, 15, 0),
#  datetime.datetime(2021, 2, 3, 14, 59),
#  datetime.datetime(2021, 2, 3, 14, 58),
#  datetime.datetime(2021, 2, 3, 14, 57),
#  datetime.datetime(2021, 2, 3, 14, 56),
#  datetime.datetime(2021, 2, 3, 14, 55),
#  datetime.datetime(2021, 2, 3, 14, 54),
#  datetime.datetime(2021, 2, 3, 14, 53),
#  datetime.datetime(2021, 2, 3, 14, 52),
#  datetime.datetime(2021, 2, 3, 14, 51),
#  datetime.datetime(2021, 2, 3, 14, 50),
#  datetime.datetime(2021, 2, 3, 14, 49),
#  datetime.datetime(2021, 2, 3, 14, 48),
#  datetime.datetime(2021, 2, 3, 14, 47),
#  datetime.datetime(2021, 2, 3, 14, 46),
#  datetime.datetime(2021, 2, 3, 14, 45),
#  datetime.datetime(2021, 2, 3, 14, 44),
#  datetime.datetime(2021, 2, 3, 14, 43),
#  datetime.datetime(2021, 2, 3, 14, 42),
#  datetime.datetime(2021, 2, 3, 14, 41),
#  datetime.datetime(2021, 2, 3, 14, 40),
#  datetime.datetime(2021, 2, 3, 14, 39),
#  datetime.datetime(2021, 2, 3, 14, 38),
#  ...]

# %%
# So the "apply()" method is slightly slower than "list comprehension" in this example. Interesting
df_btc['date'] = [datetime.fromtimestamp(ts) for ts in df_btc['unix']]

# %%
# Sort dates
df_btc.sort_values(by='date', ascending=True, ignore_index=True, inplace=True)

# %% [markdown]
# Now, we have a lot of data here, thank God (which doesn't exist), that it will be helpful in the future. But now we just want to build a preliminary project with toy data, so let's just take a sample to play with filtering by date. **Same dates as twitter extraction sample we got earlier.** <br> Let's do it baby!

# %%
df_btc = df_btc[['date', 'open', 'high', 'low', 'close', 'Volume USD']]
df_btc = df_btc.rename(columns={'Volume USD': 'volume_usd'})
df_btc.head(3)
# Out:
#                  date      open      high       low     close    volume_usd
# 0 2020-11-22 08:57:00  18494.17  18511.57  18485.07  18511.57  27241.827263
# 1 2020-11-22 08:58:00  18504.96  18517.30  18504.57  18517.30  28432.253479
# 2 2020-11-22 08:59:00  18521.33  18527.41  18511.13  18520.98  76742.234037

# %%
df_btc['date'].min(), df_btc['date'].max()
# Out:
# (Timestamp('2020-11-22 08:57:00'), Timestamp('2021-02-04 07:17:00'))

# %% [markdown]
# For the sake of simplicity, let's just take a sample... from 1st of January.

# %%
max_volume = (df_btc['volume_usd'] == df_btc['volume_usd'].max())
# Date with the greatest volume of bitcoins traded
df_btc[max_volume]['date']
# Out:
# 31994   2021-01-10 21:28:00
# Name: date, dtype: datetime64[ns]

# %%
# Preparing the df to plot it 

intraday = df_btc[(df_btc['date'] > '2021-01-10 10:00:00') & (df_btc['date'] < '2021-01-11 10:00:00')]
intraday.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
intraday.set_index('Date', inplace=True)
print(intraday.shape)
intraday.head(3)
# Out:
# (1439, 5)
#                          Open      High       Low     Close         Volume
# Date
# 2021-01-10 10:01:00  40900.89  40990.00  40900.89  40990.00  108938.474948
# 2021-01-10 10:02:00  40973.09  40980.96  40953.40  40976.80  115543.638473
# 2021-01-10 10:03:00  40962.33  41000.00  40962.33  40978.88  110602.303232

# %%
mpf.plot(intraday, type='candle', volume=True)

# %%
# # Volume of bitcoins traded in US dollars
# plt.figure(figsize=(10, 6))
# plt.plot(df_btc['date'], df_btc['volume_usd'])

# plt.title('Volume of bitcoins traded in USD')
# plt.xlabel('date (month-day hour)')
# plt.ylabel('million USD')
